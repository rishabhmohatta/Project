# %%
TASK 1

# %%
#QUESTION A
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
#OUESTION B
schema = pd.read_csv('survey_results_schema.csv')
dff_schema = pd.DataFrame(schema)
dff_schema.head(10)
# Out:
#             Column                                       QuestionText
# 0       Respondent  Randomized respondent ID number (not in order ...
# 1            Hobby                            Do you code as a hobby?
# 2       OpenSource         Do you contribute to open source projects?
# 3          Country          In which country do you currently reside?
# 4          Student  Are you currently enrolled in a formal, degree...
# 5       Employment  Which of the following best describes your cur...
# 6  FormalEducation  Which of the following best describes the high...
# 7   UndergradMajor  You previously indicated that you went to a co...
# 8      CompanySize  Approximately how many people are employed by ...
# 9          DevType  Which of the following describe you? Please se...

# %%
survey = pd.read_csv('survey_results_public.csv')
dff_survey = pd.DataFrame(survey)
# Out:
# c:\users\rishabh\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# QUESTION C

# %%
"""the ten columns we can used are 
1 Hobby : it will tell the percentage of devloper who are doing for money or passion
2 country : which country has how many devloper
3 education : combing formal education and undergradtuate column it tells us to become devloper what type of education we have to study
4 codingexperience : if some company want the experience devloper in his company so for that
5 codinghours : average time a devloper work
6 stackoverflowvisit or recommended : if an error occur to solve they recommanded stackoverflow or not 
7 stackoverflow participation : adding a answer  to other devloper programs to solve other problems or increase their knowledge
8 devtype : the field of devloper in which field the devloper use
9 language,platform : which type of programming language and platform are commonly used by devloper 
10 salary : the analysis average salary of a devloper
11 age : is devloper are young or old """
# Out:
# 'the ten columns we can used are \n1 Hobby : it will tell the percentage of devloper who are doing for money or passion\n2 country : which country has how many devloper\n3 education : combing formal education and undergradtuate column it tells us to become devloper what type of education we have to study\n4 codingexperience : if some company want the experience devloper in his company so for that\n5 codinghours : average time a devloper work\n6 stackoverflowvisit or recommended : if an error occur to solve they recommanded stackoverflow or not \n7 stackoverflow participation : adding a answer  to other devloper programs to solve other problems or increase their knowledge\n8 devtype : the field of devloper in which field the devloper use\n9 language,platform : which type of programming language and platform are commonly used by devloper \n10 salary : the analysis average salary of a devloper\n11 age : is devloper are young or old '

# %%
# QUESTION D
dff_survey['Respondent'].count()  #as respondent  column cant be null
# Out:
# 98855

# %%
# QUESTION E
dff_survey.describe()
# Out:
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# ...

# %%
# TASK 2
# Out:
# 51153

# %%
# QUESTION A
type(dff_survey['ConvertedSalary'][0])
# Out:
# numpy.float64

# %%
# QUESTION B
dff_survey['ConvertedSalary'].notnull().sum()
# Out:
# 47702

# %%
# QUESTION C
df_sal_NonNa= pd.DataFrame(dff_survey['ConvertedSalary'].dropna())

# %%
# QUESTION D
f,ax = plt.subplots(figsize = (20,10))
ax.hist(df_sal_NonNa['ConvertedSalary'],bins = 32)
plt.ylabel('frequency',color = 'red',style = 'italic')
plt.xlabel('Salary',color = 'red',style = 'italic')
# Out:
# Text(0.5, 0, 'Salary')

# %%
# QUESTION E
df_sal_low  = pd.DataFrame(df_sal_NonNa.loc[df_sal_NonNa['ConvertedSalary']<=250000])

# %%
sns.distplot(df_sal_low['ConvertedSalary'],kde=False,color = 'red',bins = 32)

# %%
# QUESTION F

# %%
sns.distplot(df_sal_NonNa['ConvertedSalary'],kde = True,hist = False, bins = 32)

# %%
sns.distplot(df_sal_low['ConvertedSalary'],kde = True,hist=False,bins=32,color = 'red')

# %%
# TASK 3
sns.set(style='whitegrid',color_codes=True)

# %%
# QUESTION A
f , ax = plt.subplots(figsize = (10,30))
sns.stripplot(x= df_sal_NonNa["ConvertedSalary"],y = dff_survey['Country'],size = 6,jitter = True)

# %%
# QUESTION B    AND QUESTION C   

df_sal_NonNa['Country'] = dff_survey['Country']

# %%
country = pd.DataFrame(df_sal_NonNa['Country'].value_counts().reset_index())

# %%
country1 = [country['Country'][0:5]

# %%
f , ax = plt.subplots()
sns.stripplot(x= df_sal_NonNa['ConvertedSalary'], order = )

# %%
# TASK 4

# %%
# QUESTION A
df_sal_NonNa['FormalEducation'] = dff_survey['FormalEducation'].str[:11]

# %%
f ,ax = plt.subplots(figsize=(10,6))
sns.swarmplot(x = df_sal_NonNa['FormalEducation'][0:101] , y = df_sal_NonNa['ConvertedSalary'][0:101])

# %%
# QUESTION B
df_sal_NonNa['Employment'] = dff_survey['Employment']

# %%
f ,ax = plt.subplots(figsize=(10,6))
sns.swarmplot(x = df_sal_NonNa['FormalEducation'][0:101] , y = df_sal_NonNa['ConvertedSalary'][0:101], hue = df_sal_NonNa['Employment'][0:101] )

# %%
# TASK 4
# QUESTION A
f ,ax = plt.subplots(figsize=(10,6))
sns.boxplot(x = df_sal_NonNa['FormalEducation'] , y = df_sal_NonNa['ConvertedSalary'])

# %%
#TASK 5
# QUESTION A
fig,ax = plt.subplots(figsize = (10,6))
size = list(df_sal_NonNa['FormalEducation'].value_counts())
label = list(df_sal_NonNa['FormalEducation'])
plt.pie(size,autopct = '%.1f')
plt.axis('equal')
# Out:
# (-1.1196721670191767,
#  1.100936769858056,
#  -1.109720228903953,
#  1.1116251534203965)
